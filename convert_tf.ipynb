# %%
from models.stylegan_generator import StyleGANGenerator

# %%
test = StyleGANGenerator('stylegan_ffhq')
# Out:
# [2020-06-23 18:47:27,318][INFO] Loading tensorflow model from `models/pretrain/karras2019stylegan-ffhq-1024x1024.pkl`.
# WARNING:tensorflow:From /summer_project_container/interfaceGAN_experiments/models/stylegan_generator.py:76: The name tf.InteractiveSession is deprecated. Please use tf.compat.v1.InteractiveSession instead.
#
# WARNING:tensorflow:From models/stylegan_tf_official/dnnlib/tflib/tfutil.py:34: The name tf.Dimension is deprecated. Please use tf.compat.v1.Dimension instead.
#
# WARNING:tensorflow:From models/stylegan_tf_official/dnnlib/tflib/tfutil.py:74: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From models/stylegan_tf_official/dnnlib/tflib/tfutil.py:128: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# ...

# %%
import numpy as np
import os

# %%
os.getcwd()
test_vec = np.load('outputs/ran_sample_0000/z.npy')

# %%
test_vec.shape
# Out:
# (20, 512)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
my_pic_path='outputs/ran_sample_0000/000000.jpg'
my_pic = cv2.imread(my_pic_path)[:,:,::-1]
my_pic.shape
plt.imshow(my_pic)
plt.show()
